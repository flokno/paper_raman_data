# %%
import pandas as pd

# %%
index_col = "frequency_cm"

df_2pdos = pd.read_csv("outfile.2pdos.csv", index_col=index_col)
df_cdos = pd.read_csv("outfile.phonon_dos_convolutions.csv", index_col=index_col)

# %%
ax = df_2pdos["2PDOS"].plot()

df_cdos["dos_weighted_convoluted"].plot(ax=ax)

ax.legend(["2PDOS", "cDOS"])

ax.get_figure().savefig("plot_gan_2pdos.png")
